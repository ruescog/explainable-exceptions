# %% [raw]
# ---
# description: Fill in a module description here
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(explain)
# Out:
# ---
#
# [source](https://github.com/ruescog/explainable-exceptions/blob/main/explainable_exceptions/core.py#L78){target="_blank" style="float:right; font-size:smaller"}
#
# ### explain
#
# >      explain (line, cell, local_ns)

# %%
#| echo: false
#| output: asis
show_doc(explain_exception)
# Out:
# ---
#
# [source](https://github.com/ruescog/explainable-exceptions/blob/main/explainable_exceptions/core.py#L55){target="_blank" style="float:right; font-size:smaller"}
#
# ### explain_exception
#
# >      explain_exception (cookies, exception_message, wait=0)

# %%
#| echo: false
#| output: asis
show_doc(login)
# Out:
# ---
#
# [source](https://github.com/ruescog/explainable-exceptions/blob/main/explainable_exceptions/core.py#L19){target="_blank" style="float:right; font-size:smaller"}
#
# ### login
#
# >      login (user:str=None, password:str=None, credentials_dir:str='.')
#
# Logs the user into the huggingface chat using the user + password or the user + credentials json.
